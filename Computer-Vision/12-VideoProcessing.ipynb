# %%
import cv2 
#1108 -> 20 -> 92
import matplotlib.pyplot as plt

# %%
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %%
video_path = (r"C:\Users\ishaan.narayan\Downloads\samples_data_vtest_new.mp4")
cap = cv2.VideoCapture(video_path)

# %%
if not cap.isOpened():
    print("Cannot Open File")
    cap.release()
    cv2.destroyAllWindows()
    exit()

# %%
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("End Of video --")
#         break  

#     frame = cv2.resize(frame, (640, 360))

#     boxes, weights = hog.detectMultiScale(frame, winStride=(8,8))
#     for (x, y, w, h) in boxes:
#         cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

#     cv2.imshow('People Detection (HOG)', frame)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#     cv2.imshow('Video Render', frame)

# %%
cap.release()
cv2.destroyAllWindows()

# %%
# providing the Out put as png and to reduce The Computations the Main Block is commented out.

# %%
image_video = r"C:\Users\ishaan.narayan\Desktop\Ishaan's Workspace\Nlp_DL\DeepLearning-NLP\Computer-Vision\Screenshot 2025-06-27 114817.png"
img = cv2.imread(image_video)

# %%
plt.imshow(img)
plt.show()
