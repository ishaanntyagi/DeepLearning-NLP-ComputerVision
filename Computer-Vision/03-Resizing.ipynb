# %%
import cv2
print(cv2.__version__)
import matplotlib.pyplot as plt
# Out:
# 4.11.0

# %%
image = cv2.imread(r"C:\Users\ishaan.narayan\Pictures\Screenshots\Screenshot 2025-06-26 111456.png")

# %%
if image is None:
    print("Error: Image not found or the path is incorrect.")
else:
    y1, y2 = 50, 200 #The vertical range
    x1, x2 = 50,200 #the Horizontal range
    cropped_image = image[y1:y2, x1:x2]
    Final_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)

# %%
A = plt.imshow(Final_image)
plt.show(A)

# %%
B = plt.imshow(image)
plt.show(B)
