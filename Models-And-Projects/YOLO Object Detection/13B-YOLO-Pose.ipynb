# %%
image_path = r"C:\Users\ishaan.narayan\Downloads\karina-carvalho-fKTKVrNqXQQ-unsplash.jpg"

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-pose.pt')

# %%
results = model(image_path)
for result in results:
    result.show()
    result.save()
# Out:
# image 1/1 C:\Users\ishaan.narayan\Downloads\karina-carvalho-fKTKVrNqXQQ-unsplash.jpg: 640x448 1 person, 57.1ms
# Speed: 2.6ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)

# %%
#loading and Previewing the new Image
import cv2 
import matplotlib.pyplot as plt
preview_image_path = r"C:\Users\ishaan.narayan\Desktop\Ishaan's Workspace\Nlp_DL\DeepLearning-NLP\Computer-Vision\results_karina-carvalho-fKTKVrNqXQQ-unsplash.jpg"
preview_image      = cv2.imread(preview_image_path)
plt.imshow(preview_image)
